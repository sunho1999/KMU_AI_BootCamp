# %%
import numpy as np
import pandas as pd

covid = pd.read_csv("./country_wise_latest.csv")
avocado = pd.read_csv("./avocado.csv")
covid
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# ### Mission
#
# 1. covid 데이터에서 100 case 대비 사망률(`Deaths/ 100 Cases`)이 가장 높은 국가는?

# %%
covid_test = covid['Country/Region'].groupby(by= covid["Deaths / 100 Cases"])
covid_max = covid_test.max()
covid_max
# Out:
# Deaths / 100 Cases
# 0.00            Vietnam
# 0.05          Singapore
# 0.15              Qatar
# 0.18             Uganda
# 0.26              Nepal
#               ...
# 13.71            France
# 14.26             Italy
# 14.79           Belgium
# 15.19    United Kingdom
# 28.56             Yemen
# Name: Country/Region, Length: 145, dtype: object

# %% [markdown]
# 2. covid 데이터에서 신규 확진자가 없는 나라중 WHO Region이 'Europe'를 모두 출력하면?
# - Hint: 한줄에 두가지 조건을 Apply하는 경우 Warning이 발생할 수 있습니다.

# %%
zero_covid = covid[covid['New cases'] == 0]
answer_df = zero_covid[zero_covid['WHO Region'] == "Europe"]
answer_df
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 56         Estonia       2034      69       1923      42          0
# 75        Holy See         12       0         12       0          0
# 95          Latvia       1219      31       1045     143          0
# 100  Liechtenstein         86       1         81       4          0
# 113         Monaco        116       4        104       8          0
# 143     San Marino        699      42        657       0          0
# 157          Spain     272421   28432     150376   93613          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 56            0              1                3.39                  94.54
# 75            0              0                0.00                 100.00
# 95            0              0                2.54                  85.73
# 100           0              0                1.16                  94.19
# ...

# %% [markdown]
# 3. [다음 데이터](https://www.kaggle.com/neuromusic/avocado-prices)를 이용해 각 Region별로 아보카도가 가장 비싼 평균가격(AveragePrcie)를 출력하면?

# %%
avocado_region = avocado['AveragePrice'].groupby(by = avocado['region'])
avocado_region.mean().max()
# Out:
# 1.8186390532544363
